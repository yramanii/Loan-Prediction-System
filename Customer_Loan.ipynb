# %% [markdown]
# <a href="https://colab.research.google.com/github/ShahedSabab/Customer-loan-enquiry/blob/master/Customer_Loan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import regularizers
from collections import Counter
import pickle
import joblib
import warnings
from pylab import rcParams
from matplotlib import rc
warnings.filterwarnings("ignore")
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
RANDOM_SEED = 20
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Define Model and plot methods

# %%
def create_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(400, activation = 'relu', kernel_initializer = 'random_normal', input_dim = X_train.shape[1]),
        tf.keras.layers.Dropout(rate = dropout_prob),
        tf.keras.layers.Dense(400, activation = 'relu', kernel_initializer = 'random_normal', kernel_regularizer=regularizers.l1(regulizer)),
        tf.keras.layers.Dropout(rate = dropout_prob),
        tf.keras.layers.Dense(200, activation = 'relu', kernel_initializer = 'random_normal'),
        tf.keras.layers.Dense(1, activation = 'sigmoid', kernel_initializer = 'random_normal')
        ])
    print(model.summary())
    return model

def plot_graphs(f, history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

# %% [markdown]
# # Initialize variables

# %%
#initialize variables 
num_epoch = 100
batch_size = 20
learning_rate = 0.01
regulizer = 0.01
verbose = 2
validation_split = 0.2
dropout_prob = 0.5
test_size = 0.2
rcParams['figure.figsize'] = 12,8

# %% [markdown]
# # Read Data

# %%
# !gdown --id 1_lOntWqoxT0vwWkCq8g0BehilnpAQGKH --output bankloan.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1_lOntWqoxT0vwWkCq8g0BehilnpAQGKH
# To: b:\Other Stuffs\final year project code\Django-app\bankloan.csv
#
#   0%|          | 0.00/38.0k [00:00<?, ?B/s]
# 100%|██████████| 38.0k/38.0k [00:00<?, ?B/s]

# %%
df = pd.read_csv("bankloan.csv")

# %% [markdown]
# # Drop missing values

# %%
df = df.dropna()

# %%
df.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
# 5  LP001011   Male     Yes         2.0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y
# 5             1.0         Urban           Y

# %% [markdown]
# # Drop unnecessary features

# %%
df = df.drop('Loan_ID', axis = 1)

# %% [markdown]
# # Check data distribution

# %%
chart = sns.countplot(df.Loan_Status)
plt.title("Number of examples per intent")
chart.set_xticklabels(chart.get_xticklabels(), rotation = 0, horizontalalignment= 'right')
# Out:
# [Text(0, 0, 'N'), Text(1, 0, 'Y')]

# %% [markdown]
# # Convert categorical features

# %%
pr_dfy = df['Loan_Status']
pr_dfx = df.drop('Loan_Status', axis = 1)
d_x  = pd.get_dummies(pr_dfx)
d_y = pr_dfy.map(dict(Y=1, N=0))

# %% [markdown]
# # Oversampling minority class

# %%
sm = SMOTE()
X1, y = sm.fit_sample(d_x, d_y)

# %% [markdown]
# # Check distribution after sampling

# %%
chart = sns.countplot(y)
plt.title("Number of examples per intent")
chart.set_xticklabels(chart.get_xticklabels(), rotation = 0, horizontalalignment= 'right')
# Out:
# [Text(0, 0, '0'), Text(1, 0, '1')]

# %% [markdown]
# # Normalize the data

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X1)

fileName = 'scaler.pkl'
joblib.dump(scaler, fileName)
# Out:
# ['scaler.pkl']

# %% [markdown]
# # Train-test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = test_size, random_state=RANDOM_SEED, shuffle = True, stratify=y)

# %% [markdown]
# # Define model

# %%
model = create_model()
opt = tf.optimizers.Adam()
model.compile(loss='binary_crossentropy', optimizer = opt, metrics = ['accuracy'])


history = model.fit(X_train, 
                    y_train, 
                    epochs = num_epoch,
                    validation_split=validation_split,
                    batch_size = batch_size,
                    verbose=verbose)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 400)               7200
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 400)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 400)               160400
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 400)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 200)               80200
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 201
# =================================================================
# Total params: 248,001
# Trainable params: 248,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 424 samples, validate on 107 samples
# Epoch 1/100
# 424/424 - 1s - loss: 50.3032 - accuracy: 0.5448 - val_loss: 35.9209 - val_accuracy: 0.5701
# Epoch 2/100
# 424/424 - 0s - loss: 26.9622 - accuracy: 0.6533 - val_loss: 18.1429 - val_accuracy: 0.7850
# Epoch 3/100
# 424/424 - 0s - loss: 13.0891 - accuracy: 0.7170 - val_loss: 8.3657 - val_accuracy: 0.7196
# Epoch 4/100
# 424/424 - 0s - loss: 5.9256 - accuracy: 0.6675 - val_loss: 3.7500 - val_accuracy: 0.7196
# Epoch 5/100
# 424/424 - 0s - loss: 2.7510 - accuracy: 0.7052 - val_loss: 1.9071 - val_accuracy: 0.6449
# Epoch 6/100
# 424/424 - 0s - loss: 1.5520 - accuracy: 0.7170 - val_loss: 1.2616 - val_accuracy: 0.7850
# Epoch 7/100
# 424/424 - 0s - loss: 1.1735 - accuracy: 0.6887 - val_loss: 1.0914 - val_accuracy: 0.7664
# Epoch 8/100
# 424/424 - 0s - loss: 1.1097 - accuracy: 0.6651 - val_loss: 1.0574 - val_accuracy: 0.7383
# Epoch 9/100
# 424/424 - 0s - loss: 1.0102 - accuracy: 0.7241 - val_loss: 0.9653 - val_accuracy: 0.7850
# Epoch 10/100
# 424/424 - 0s - loss: 1.0001 - accuracy: 0.7170 - val_loss: 0.9465 - val_accuracy: 0.8131
# Epoch 11/100
# 424/424 - 0s - loss: 0.9740 - accuracy: 0.7288 - val_loss: 1.0469 - val_accuracy: 0.5794
# Epoch 12/100
# 424/424 - 0s - loss: 1.0357 - accuracy: 0.7123 - val_loss: 0.9913 - val_accuracy: 0.7757
# Epoch 13/100
# 424/424 - 0s - loss: 0.9650 - accuracy: 0.7170 - val_loss: 0.9118 - val_accuracy: 0.8131
# Epoch 14/100
# 424/424 - 0s - loss: 0.8940 - accuracy: 0.7665 - val_loss: 0.9160 - val_accuracy: 0.7290
# Epoch 15/100
# 424/424 - 0s - loss: 0.9516 - accuracy: 0.7264 - val_loss: 0.9037 - val_accuracy: 0.8224
# Epoch 16/100
# 424/424 - 0s - loss: 0.9205 - accuracy: 0.7288 - val_loss: 0.8692 - val_accuracy: 0.8131
# Epoch 17/100
# 424/424 - 0s - loss: 0.8829 - accuracy: 0.7712 - val_loss: 0.8456 - val_accuracy: 0.8598
# Epoch 18/100
# 424/424 - 0s - loss: 0.8938 - accuracy: 0.7665 - val_loss: 0.8399 - val_accuracy: 0.8598
# Epoch 19/100
# 424/424 - 0s - loss: 0.8767 - accuracy: 0.7807 - val_loss: 0.8787 - val_accuracy: 0.7944
# Epoch 20/100
# 424/424 - 0s - loss: 0.8957 - accuracy: 0.7759 - val_loss: 0.9234 - val_accuracy: 0.6916
# Epoch 21/100
# 424/424 - 0s - loss: 0.8812 - accuracy: 0.7642 - val_loss: 0.8464 - val_accuracy: 0.8131
# Epoch 22/100
# 424/424 - 0s - loss: 0.8722 - accuracy: 0.7665 - val_loss: 0.8120 - val_accuracy: 0.8411
# Epoch 23/100
# 424/424 - 0s - loss: 0.8383 - accuracy: 0.7759 - val_loss: 0.7937 - val_accuracy: 0.8692
# Epoch 24/100
# 424/424 - 0s - loss: 0.8294 - accuracy: 0.7759 - val_loss: 0.7975 - val_accuracy: 0.8692
# Epoch 25/100
# 424/424 - 0s - loss: 0.8420 - accuracy: 0.7665 - val_loss: 0.8637 - val_accuracy: 0.7757
# Epoch 26/100
# 424/424 - 0s - loss: 0.9098 - accuracy: 0.7382 - val_loss: 0.8450 - val_accuracy: 0.8224
# Epoch 27/100
# 424/424 - 0s - loss: 0.8384 - accuracy: 0.8090 - val_loss: 0.7725 - val_accuracy: 0.8598
# Epoch 28/100
# 424/424 - 0s - loss: 0.8084 - accuracy: 0.7830 - val_loss: 0.7716 - val_accuracy: 0.8505
# Epoch 29/100
# 424/424 - 0s - loss: 0.7830 - accuracy: 0.8019 - val_loss: 0.7836 - val_accuracy: 0.8131
# Epoch 30/100
# 424/424 - 0s - loss: 0.7902 - accuracy: 0.7995 - val_loss: 0.7744 - val_accuracy: 0.8692
# Epoch 31/100
# 424/424 - 0s - loss: 0.8216 - accuracy: 0.7759 - val_loss: 0.7611 - val_accuracy: 0.8598
# Epoch 32/100
# 424/424 - 0s - loss: 0.7989 - accuracy: 0.7925 - val_loss: 0.7511 - val_accuracy: 0.8598
# Epoch 33/100
# 424/424 - 0s - loss: 0.7815 - accuracy: 0.8208 - val_loss: 0.7533 - val_accuracy: 0.8598
# Epoch 34/100
# 424/424 - 0s - loss: 0.7783 - accuracy: 0.7972 - val_loss: 0.7543 - val_accuracy: 0.8598
# Epoch 35/100
# 424/424 - 0s - loss: 0.8094 - accuracy: 0.7972 - val_loss: 0.7420 - val_accuracy: 0.8598
# Epoch 36/100
# 424/424 - 0s - loss: 0.7532 - accuracy: 0.8184 - val_loss: 0.7628 - val_accuracy: 0.8411
# Epoch 37/100
# 424/424 - 0s - loss: 0.7810 - accuracy: 0.8066 - val_loss: 0.7553 - val_accuracy: 0.8411
# Epoch 38/100
# 424/424 - 0s - loss: 0.7841 - accuracy: 0.7877 - val_loss: 0.7608 - val_accuracy: 0.8411
# Epoch 39/100
# 424/424 - 0s - loss: 0.7920 - accuracy: 0.7901 - val_loss: 0.7393 - val_accuracy: 0.8598
# Epoch 40/100
# 424/424 - 0s - loss: 0.7616 - accuracy: 0.7948 - val_loss: 0.7366 - val_accuracy: 0.8598
# Epoch 41/100
# 424/424 - 0s - loss: 0.7878 - accuracy: 0.7901 - val_loss: 0.7490 - val_accuracy: 0.8598
# Epoch 42/100
# 424/424 - 0s - loss: 0.7750 - accuracy: 0.7995 - val_loss: 0.7472 - val_accuracy: 0.8598
# Epoch 43/100
# 424/424 - 0s - loss: 0.7717 - accuracy: 0.8042 - val_loss: 0.8052 - val_accuracy: 0.8318
# Epoch 44/100
# 424/424 - 0s - loss: 0.7897 - accuracy: 0.7925 - val_loss: 0.7801 - val_accuracy: 0.8411
# Epoch 45/100
# 424/424 - 0s - loss: 0.7784 - accuracy: 0.8090 - val_loss: 0.7625 - val_accuracy: 0.8505
# Epoch 46/100
# 424/424 - 0s - loss: 0.7624 - accuracy: 0.8090 - val_loss: 0.7555 - val_accuracy: 0.8505
# Epoch 47/100
# 424/424 - 0s - loss: 0.7816 - accuracy: 0.7925 - val_loss: 0.8236 - val_accuracy: 0.7850
# Epoch 48/100
# 424/424 - 0s - loss: 0.7788 - accuracy: 0.8137 - val_loss: 0.7667 - val_accuracy: 0.8785
# Epoch 49/100
# 424/424 - 0s - loss: 0.7600 - accuracy: 0.8066 - val_loss: 0.7663 - val_accuracy: 0.8411
# Epoch 50/100
# 424/424 - 0s - loss: 0.7734 - accuracy: 0.7995 - val_loss: 0.7360 - val_accuracy: 0.8598
# Epoch 51/100
# 424/424 - 0s - loss: 0.7562 - accuracy: 0.8019 - val_loss: 0.7559 - val_accuracy: 0.8411
# Epoch 52/100
# 424/424 - 0s - loss: 0.7568 - accuracy: 0.8019 - val_loss: 0.7707 - val_accuracy: 0.8224
# Epoch 53/100
# 424/424 - 0s - loss: 0.7294 - accuracy: 0.8278 - val_loss: 0.7485 - val_accuracy: 0.8318
# Epoch 54/100
# 424/424 - 0s - loss: 0.7405 - accuracy: 0.8278 - val_loss: 0.7388 - val_accuracy: 0.8505
# Epoch 55/100
# 424/424 - 0s - loss: 0.7329 - accuracy: 0.8184 - val_loss: 0.7204 - val_accuracy: 0.8318
# Epoch 56/100
# 424/424 - 0s - loss: 0.7306 - accuracy: 0.8066 - val_loss: 0.7277 - val_accuracy: 0.8598
# Epoch 57/100
# 424/424 - 0s - loss: 0.7143 - accuracy: 0.8184 - val_loss: 0.7230 - val_accuracy: 0.8598
# Epoch 58/100
# 424/424 - 0s - loss: 0.7751 - accuracy: 0.8137 - val_loss: 0.7634 - val_accuracy: 0.8505
# Epoch 59/100
# 424/424 - 0s - loss: 0.7241 - accuracy: 0.8255 - val_loss: 0.7328 - val_accuracy: 0.8318
# Epoch 60/100
# 424/424 - 0s - loss: 0.7210 - accuracy: 0.8066 - val_loss: 0.7430 - val_accuracy: 0.8224
# Epoch 61/100
# 424/424 - 0s - loss: 0.7254 - accuracy: 0.8113 - val_loss: 0.7214 - val_accuracy: 0.8411
# Epoch 62/100
# 424/424 - 0s - loss: 0.7192 - accuracy: 0.8090 - val_loss: 0.7247 - val_accuracy: 0.8505
# Epoch 63/100
# 424/424 - 0s - loss: 0.7120 - accuracy: 0.8137 - val_loss: 0.7173 - val_accuracy: 0.8505
# Epoch 64/100
# 424/424 - 0s - loss: 0.7489 - accuracy: 0.7995 - val_loss: 0.7218 - val_accuracy: 0.8505
# Epoch 65/100
# 424/424 - 0s - loss: 0.7240 - accuracy: 0.8184 - val_loss: 0.7526 - val_accuracy: 0.8318
# Epoch 66/100
# 424/424 - 0s - loss: 0.6958 - accuracy: 0.8184 - val_loss: 0.7519 - val_accuracy: 0.8505
# Epoch 67/100
# 424/424 - 0s - loss: 0.7205 - accuracy: 0.8090 - val_loss: 0.7332 - val_accuracy: 0.8505
# Epoch 68/100
# 424/424 - 0s - loss: 0.6989 - accuracy: 0.8302 - val_loss: 0.7246 - val_accuracy: 0.8598
# Epoch 69/100
# 424/424 - 0s - loss: 0.6938 - accuracy: 0.8231 - val_loss: 0.7099 - val_accuracy: 0.8598
# Epoch 70/100
# 424/424 - 0s - loss: 0.7053 - accuracy: 0.8160 - val_loss: 0.7363 - val_accuracy: 0.8411
# Epoch 71/100
# 424/424 - 0s - loss: 0.7168 - accuracy: 0.8208 - val_loss: 0.7360 - val_accuracy: 0.8411
# Epoch 72/100
# 424/424 - 0s - loss: 0.7188 - accuracy: 0.8231 - val_loss: 0.7637 - val_accuracy: 0.8318
# Epoch 73/100
# 424/424 - 0s - loss: 0.7251 - accuracy: 0.8255 - val_loss: 0.7396 - val_accuracy: 0.8411
# Epoch 74/100
# 424/424 - 0s - loss: 0.7063 - accuracy: 0.8090 - val_loss: 0.7446 - val_accuracy: 0.8131
# Epoch 75/100
# 424/424 - 0s - loss: 0.7316 - accuracy: 0.8184 - val_loss: 0.7273 - val_accuracy: 0.8692
# Epoch 76/100
# 424/424 - 0s - loss: 0.6976 - accuracy: 0.8373 - val_loss: 0.7631 - val_accuracy: 0.8037
# Epoch 77/100
# 424/424 - 0s - loss: 0.7110 - accuracy: 0.8373 - val_loss: 0.7371 - val_accuracy: 0.8505
# Epoch 78/100
# 424/424 - 0s - loss: 0.6993 - accuracy: 0.8349 - val_loss: 0.7295 - val_accuracy: 0.8505
# Epoch 79/100
# 424/424 - 0s - loss: 0.7175 - accuracy: 0.8255 - val_loss: 0.8016 - val_accuracy: 0.8037
# Epoch 80/100
# 424/424 - 0s - loss: 0.7163 - accuracy: 0.8208 - val_loss: 0.8163 - val_accuracy: 0.7850
# Epoch 81/100
# 424/424 - 0s - loss: 0.7343 - accuracy: 0.8208 - val_loss: 0.7392 - val_accuracy: 0.8411
# Epoch 82/100
# 424/424 - 0s - loss: 0.7034 - accuracy: 0.8373 - val_loss: 0.7299 - val_accuracy: 0.8411
# Epoch 83/100
# 424/424 - 0s - loss: 0.7047 - accuracy: 0.8184 - val_loss: 0.7572 - val_accuracy: 0.8224
# Epoch 84/100
# 424/424 - 0s - loss: 0.7080 - accuracy: 0.8160 - val_loss: 0.7187 - val_accuracy: 0.8505
# Epoch 85/100
# 424/424 - 0s - loss: 0.7114 - accuracy: 0.8137 - val_loss: 0.7177 - val_accuracy: 0.8598
# Epoch 86/100
# 424/424 - 0s - loss: 0.6905 - accuracy: 0.8278 - val_loss: 0.7175 - val_accuracy: 0.8505
# Epoch 87/100
# 424/424 - 0s - loss: 0.6740 - accuracy: 0.8231 - val_loss: 0.7763 - val_accuracy: 0.8131
# Epoch 88/100
# 424/424 - 0s - loss: 0.7036 - accuracy: 0.8137 - val_loss: 0.7130 - val_accuracy: 0.8411
# Epoch 89/100
# 424/424 - 0s - loss: 0.6969 - accuracy: 0.8255 - val_loss: 0.7088 - val_accuracy: 0.8505
# Epoch 90/100
# 424/424 - 0s - loss: 0.6859 - accuracy: 0.8349 - val_loss: 0.7270 - val_accuracy: 0.8411
# Epoch 91/100
# 424/424 - 0s - loss: 0.6847 - accuracy: 0.8184 - val_loss: 0.7180 - val_accuracy: 0.8505
# Epoch 92/100
# 424/424 - 0s - loss: 0.6901 - accuracy: 0.8255 - val_loss: 0.7228 - val_accuracy: 0.8318
# Epoch 93/100
# 424/424 - 0s - loss: 0.6789 - accuracy: 0.8349 - val_loss: 0.7409 - val_accuracy: 0.8224
# Epoch 94/100
# 424/424 - 0s - loss: 0.6586 - accuracy: 0.8325 - val_loss: 0.7457 - val_accuracy: 0.8131
# Epoch 95/100
# 424/424 - 0s - loss: 0.6586 - accuracy: 0.8491 - val_loss: 0.7791 - val_accuracy: 0.8037
# Epoch 96/100
# 424/424 - 0s - loss: 0.6869 - accuracy: 0.8255 - val_loss: 0.7134 - val_accuracy: 0.8411
# Epoch 97/100
# 424/424 - 0s - loss: 0.6626 - accuracy: 0.8396 - val_loss: 0.7038 - val_accuracy: 0.8692
# Epoch 98/100
# 424/424 - 0s - loss: 0.6559 - accuracy: 0.8349 - val_loss: 0.6950 - val_accuracy: 0.8598
# Epoch 99/100
# 424/424 - 0s - loss: 0.6666 - accuracy: 0.8325 - val_loss: 0.7170 - val_accuracy: 0.8411
# Epoch 100/100
# 424/424 - 0s - loss: 0.6819 - accuracy: 0.8255 - val_loss: 0.7207 - val_accuracy: 0.8318

# %% [markdown]
# # Plot loss accuracy

# %%
#plot loss and accuracy 
f1 = plt.figure()
plot_graphs(f1,history, "accuracy")
f2 = plt.figure()
plot_graphs(f2,history, "loss")

# %% [markdown]
# # Evaluate Model

# %%
loss, acc = model.evaluate(X_test,  y_test, verbose=2)

print("Accuracy", acc)
print("Loss", loss)
# Out:
# 133/133 - 0s - loss: 0.6260 - accuracy: 0.8797
# Accuracy 0.87969923
# Loss 0.6260085692979339

# %% [markdown]
# # Confusion Metrix

# %%
y_pred = model.predict(X_test)
y_pred = (y_pred>0.60)

cm = confusion_matrix(y_test, y_pred)
ax = plt.subplot()
sns.heatmap(cm, annot = True, ax = ax)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(['No', 'Yes'])
ax.yaxis.set_ticklabels(['No', 'Yes'])
# Out:
# [Text(0, 0.5, 'No'), Text(0, 1.5, 'Yes')]

# %% [markdown]
# # Save model

# %%
# fileName = 'customer_loan.pkl'
# joblib.dump(model, fileName)
file = 'customer_loan.h5'
model.save(file)
